# %%
import pandas as pd
from numpy import array
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.4f' % x)
import seaborn as sns
sns.set_context("paper", font_scale=1.3)
sns.set_style('white')
import warnings
warnings.filterwarnings('ignore')
from time import time
import matplotlib.ticker as tkr
from scipy import stats
from statsmodels.tsa.stattools import adfuller
from sklearn import preprocessing
from statsmodels.tsa.stattools import pacf
# %matplotlib inline

import math
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from keras.callbacks import EarlyStopping

from keras.layers import LeakyReLU

from statistics import mean
from datetime import date
import datetime
import os
from sklearn.utils import check_array as check_arrays
from math import sqrt

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
# Out:
# Using TensorFlow backend.

# %%
# Create folder to save results in
identify = 'TimeSeriesStackedLSTMNorm2'
folder_name = '/Users/clausholm/Documents/Python/Master_thesis/Data/test_results/'+identify
#os.mkdir(folder_name)

# Load Dataset
df = pd.read_csv('datasets/Dataset_DailyPlays_DomainFeatures.csv', sep=';', index_col=0, decimal=',')
df = df.drop(columns=['Slope28', 'ArtistPopularity', 'Slope56','FirstWeek','Label 2'])

# Set dataset range
df_range = '160'
df = df.loc[:, :df_range]
df
# Out:
#                                                       1    2    3    4    5  \
# Adel Tawil - Unsere Lieder                           35   33   61   54  146
# Alec Benjamin Feat. Alessia Cara - Let Me Down ...    2    7   12   13   21
# Andreas Bourani - Auf uns                             1    1    3    3    2
# Annenmaykantereit - Marie                            34   57   84   99  119
# Ariana Grande - 7 rings                             231  272  279  302  325
# Ava Max - So Am I                                    82  111  123   97  105
# Ava Max - Sweet but Psycho                           72  158  184  208  188
# Bausa - Was Du Liebe nennst                           1    3    2    4    8
# C Arma - Yapma - Radio Edit                           2    5    2    0    2
# Calvin Harris & Rag'n'bone Man - Giant              111  128  196  221  307
# Camila Cabello feat. Young Thug - Havana             74  117   99  143  123
# Childish Gambino - This Is America                   25   51   46   48   37
# Chris Brown - Undecided                              41   68   75  108  111
# Christine and The Queens - Doesn't matter_Engli...    2    1    0    3    3
# David Guetta ft. Bebe Rexha J Balvin - Say My Name   22   27   21   20   17
# Daya - New                                            1    1    1    3    3
# Dean Lewis - Be Alright                               5    9    9   14   12
# Dermot Kennedy - Power Over Me                       17   30   31   35   38
# Die Lochis - Lieblingslied                            2    3    9   10    7
# DJ Regard - Ride It                                   1    0    0    0    1
# Dj Snake feat. Selena Gomez, Ozuna, Cardi B - T...   30   31   43   51   64
# Dominic Fike - 3 Nights                               9   13   13   12   14
# Dotan - Numb                                         43   70   77   81   68
# Dynoro & Gigi D'agostino - In My Mind                36   59   74   70   79
# Gaullin - Moonlight                                   1    2    3    5    3
# George Ezra - Pretty Shining People                  85  222  177  287  204
# GestÃ¶rt aber Geil & Koby Funk feat. Wincent We...    4    2    6   13    8
# GestÃ¶rt aber Geil feat. Sebastian HÃ¤mer - Ich...   17   22   30   38   26
# Glasperlenspiel - Geiles Leben                       20   35   25   25   28
# Joel Brandenstein - Diese Liebe                       8    0    2    0    0
# ...                                                 ...  ...  ...  ...  ...
# Peter Fox - Alles Neu                                 4    2    4    5    2
# Philipp Dittberner - Das ist dein Leben               7   12   13   16   26
# Pietro Lombardi - Nur Ein Tanz                       23   36   31   42   46
# Pietro Lombardi - PhÃ¤nomenal                        23   42   43   44   40
# Post Malone - Circles                                36   44   79  151  141
# Rebecca Ferguson - Bones                              2    0    0    5    1
# Robyn - Honey                                         3    5    2    4    7
# RosalÃ­a - MALAMENTE (Cap.1: Augurio)                
# RosalÃ­a - MALAMENTE (Cap.1: Augurio)                 6   11    8    7    6
# Sam Smith - How Do You Sleep?                       235  290  288  276  330
# Sarah Connor - Ich wÃ¼nsch dir                        8    6   29   29   35
# Sarah Connor - Vincent                               81  101  187  168  193
# Sarah Connor - Wie schÃ¶n du bist                    48   25   59   51   47
# Shawn Mendes & Camila Cabello - SeÃ±orita           744  750  769  781  835
# Shirin David - Fliegst Du mit                        37   38   27   33   41
# Skott - Mermaid                                      21   23   20   24   15
# Soleima - Low Life                                    0    0    0    1    1
# Superorganism - Everybody Wants To Be Famous         52   48   54   59   72
# Taylor Swift - You Need To Calm Down                199  205  226  297  362
# Taylor Swift feat. Brendon Urie - Me!               407  525  486  533  535
# The Script - The Last Time                           27   35   55   83   39
# TiÃ«sto, Dzeko feat. Preme, Post Malone - Jacki...   24   22   35   16   30
# Tim Bendzko - Keine Maschine                        206  203  270  266  333
# Tones And I - Dance Monkey                          982  909  807  941  969
# Wincent Weiss - Hier mit dir                        169  137  123  134  200
# Wincent Weiss - Kaum Erwarten                       191  149  247  208  207
# Xavier Naidoo - Bitte hÃ¶r nicht auf zu trÃ¤umen      6    5    5    2    2
# Xavier Naidoo - Gute Zeiten (mit MoTrip)             96   84   89  110  101
# Younotus & Janieck & Senex - Narcotic                92   91   97   93  102
# Yves Tumor - Applaud                                  1    0    0    1    0
# Zhu - Faded                                           7    9    4    7   11
#
#                                                     ...   151   152   153  \
# Adel Tawil - Unsere Lieder                          ...    33    35    34
# Alec Benjamin Feat. Alessia Cara - Let Me Down ...  ...   892   807   834
# Andreas Bourani - Auf uns                           ...   608   601   636
# Annenmaykantereit - Marie                           ...    31    33    32
# Ariana Grande - 7 rings                             ...   180   168   173
# Ava Max - So Am I                                   ...   705   756   705
# Ava Max - Sweet but Psycho                          ...   864   869   919
# Bausa - Was Du Liebe nennst                         ...   360   306   287
# C Arma - Yapma - Radio Edit                         ...     1     1     3
# Calvin Harris & Rag'n'bone Man - Giant              ...   650   718   679
# Camila Cabello feat. Young Thug - Havana            ...   907   852   846
# Childish Gambino - This Is America                  ...    34    36    32
# Chris Brown - Undecided                             ...    24    21    40
# Christine and The Queens - Doesn't matter_Engli...  ...     0     0     1
# David Guetta ft. Bebe Rexha J Balvin - Say My Name  ...   485   487   478
# Daya - New                                          ...     1     0     1
# Dean Lewis - Be Alright                             ...  1046  1101  1083
# Dermot Kennedy - Power Over Me                      ...   821   874   803
# Die Lochis - Lieblingslied                          ...    18    17    16
# DJ Regard - Ride It                                 ...  1239  1241  1217
# Dj Snake feat. Selena Gomez, Ozuna, Cardi B - T...  ...   183   192   182
# Dominic Fike - 3 Nights                             ...   471   398   448
# Dotan - Numb                                        ...     4     4     2
# Dynoro & Gigi D'agostino - In My Mind               ...  1071  1013  1041
# Gaullin - Moonlight                                 ...   237   241   233
# George Ezra - Pretty Shining People                 ...    14    17    70
# GestÃ¶rt aber Geil & Koby Funk feat. Wincent We...  ...   138   170   194
# GestÃ¶rt aber Geil feat. Sebastian HÃ¤mer - Ich...  ...   154   128   145
# Glasperlenspiel - Geiles Leben                      ...    31    36    24
# Joel Brandenstein - Diese Liebe                     ...     2     0     1
# ...                                                 ...   ...   ...   ...
# Peter Fox - Alles Neu                               ...     2    12    12
# Philipp Dittberner - Das ist dein Leben             ...   402   380   344
# Pietro Lombardi - Nur Ein Tanz                      ...     9     6     7
# Pietro Lombardi - PhÃ¤nomenal                       ...    21    23    24
# Post Malone - Circles                               ...  1057  1030   972
# Rebecca Ferguson - Bones                            ...     0     0     0
# Robyn - Honey                                       ...     7     6     8
# RosalÃ­a - MALAMENTE (Cap.1: Augurio)               ...     4    14    10
# Sam Smith - How Do You Sleep?                       ...   223   168   285
# Sarah Connor - Ich wÃ¼nsch dir                      ...   315   281   318
# Sarah Connor - Vincent                              ...   212   210   156
# Sarah Connor - Wie schÃ¶n du bist                   ...   271   267   251
# Shawn Mendes & Camila Cabello - SeÃ±orita           ...   664   592   575
# Shirin David - Fliegst Du mit                       ...     1     1     2
# Skott - Mermaid                                     ...     1     0     1
# Soleima - Low Life                                  ...     2     1     1
# Superorganism - Everybody Wants To Be Famous        ...    10    11     6
# Taylor Swift - You Need To Calm Down                ...   155   147   148
# Taylor Swift feat. Brendon Urie - Me!               ...   162   188   156
# The Script - The Last Time                          ...     3     8     1
# TiÃ«sto, Dzeko feat. Preme, Post Malone - Jacki...  ...   328   360   352
# Tim Bendzko - Keine Maschine                        ...   189   170   162
# Tones And I - Dance Monkey                          ...   778   773   738
# Wincent Weiss - Hier mit dir                        ...   683   633   609
# Wincent Weiss - Kaum Erwarten                       ...   380   414   388
# Xavier Naidoo - Bitte hÃ¶r nicht auf zu trÃ¤umen    ...     2     8     3
# Xavier Naidoo - Gute Zeiten (mit MoTrip)            ...    13    10     8
# Younotus & Janieck & Senex - Narcotic               ...  1151  1177  1102
# Yves Tumor - Applaud                                ...     0     2     0
# Zhu - Faded                                         ...   127   111   113
#
#                                                      154   155   156   157  \
# Adel Tawil - Unsere Lieder                            45    29    40    47
# Alec Benjamin Feat. Alessia Cara - Let Me Down ...   762   830   828   833
# Andreas Bourani - Auf uns                            612   608   594   599
# Annenmaykantereit - Marie                             29    35    33    28
# Ariana Grande - 7 rings                              158   162   173   154
# Ava Max - So Am I                                    667   734   687   713
# Ava Max - Sweet but Psycho                           930   876   896   837
# Bausa - Was Du Liebe nennst                          319   329   343   303
# C Arma - Yapma - Radio Edit                            1     0     1     1
# Calvin Harris & Rag'n'bone Man - Giant               665   702   655   729
# Camila Cabello feat. Young Thug - Havana             876   799   794   842
# Childish Gambino - This Is America                    37    45    46    47
# Chris Brown - Undecided                               35    41    35    40
# Christine and The Queens - Doesn't matter_Engli...     0     0     0     0
# David Guetta ft. Bebe Rexha J Balvin - Say My Name   461   487   448   517
# Daya - New                                             0     0     1     0
# Dean Lewis - Be Alright                             1068   989  1016  1104
# Dermot Kennedy - Power Over Me                       854   793   820   807
# Die Lochis - Lieblingslied                            19    18    10    11
# DJ Regard - Ride It                                 1224  1149  1238  1101
# Dj Snake feat. Selena Gomez, Ozuna, Cardi B - T...   184   221   189   180
# Dominic Fike - 3 Nights                              321   368   329   379
# Dotan - Numb                                           5     6     7     3
# Dynoro & Gigi D'agostino - In My Mind               1030  1081  1033  1054
# Gaullin - Moonlight                                  235   275   278   250
# George Ezra - Pretty Shining People                   21    16    46     6
# GestÃ¶rt aber Geil & Koby Funk feat. Wincent We...   163   144   137   165
# GestÃ¶rt aber Geil feat. Sebastian HÃ¤mer - Ich...   139   128   134   188
# Glasperlenspiel - Geiles Leben                        27    22    26    24
# Joel Brandenstein - Diese Liebe                        1     0     1     0
# ...                                                  ...   ...   ...   ...
# Peter Fox - Alles Neu                                  7     8    10     7
# Philipp Dittberner - Das ist dein Leben              356   349   415   350
# Pietro Lombardi - Nur Ein Tanz                        11     9     8     7
# Pietro Lombardi - PhÃ¤nomenal                         18    23    24    24
# Post Malone - Circles                               1007  1026  1042  1066
# Rebecca Ferguson - Bones                               0     0     0     0
# Robyn - Honey                                          5     8     9     8
# RosalÃ­a - MALAMENTE (Cap.1: Augurio)
# RosalÃ­a - MALAMENTE (Cap.1: Augurio)                 11    10     5
# Sam Smith - How Do You Sleep?                        193   231   264
# Sarah Connor - Ich wÃ¼nsch dir                       337   294   271
# Sarah Connor - Vincent                               144   156   173
# Sarah Connor - Wie schÃ¶n du bist                    243   238   255
# Shawn Mendes & Camila Cabello - SeÃ±orita            509   563   468
# Shirin David - Fliegst Du mit                          4     2     0
# Skott - Mermaid                                        0     1     0
# Soleima - Low Life                                     1     1     2
# Superorganism - Everybody Wants To Be Famous          13     9    10
# Taylor Swift - You Need To Calm Down                 197   123   146
# Taylor Swift feat. Brendon Urie - Me!                153   167   156
# The Script - The Last Time                             1     3     7
# TiÃ«sto, Dzeko feat. Preme, Post Malone - Jacki...   300   314   306
# Tim Bendzko - Keine Maschine                         250   196   143
# Tones And I - Dance Monkey                           722   774   793
# Wincent Weiss - Hier mit dir                         513   543   482
# Wincent Weiss - Kaum Erwarten                        325   314   348
# Xavier Naidoo - Bitte hÃ¶r nicht auf zu trÃ¤umen      10     3    10
# Xavier Naidoo - Gute Zeiten (mit MoTrip)               8     8    10
# Younotus & Janieck & Senex - Narcotic               1113  1143  1128
# Yves Tumor - Applaud                                   0     0     0
# Zhu - Faded                                          114   120   105
#
# [96 rows x 160 columns]

# %%
# Define dataset with songs to test on
list_of_test_songs = ['Katy Perry - Never Really Over' , 
              'Taylor Swift - You Need To Calm Down', 
              'Shawn Mendes & Camila Cabello - SeÃ±orita', 
              'Ava Max - So Am I', 
              'Andreas Bourani - Auf uns', 
              'Meduza feat. Goodboys - Piece Of Your Heart', 
              'Pietro Lombardi - Nur Ein Tanz', 
              'Loud Luxury feat. brando - Body', 
              'Mark Forster - Sowieso', 
              'Camila Cabello feat. Young Thug - Havana',  ] 

df_test = df.loc[list_of_test_songs]
df_test
# Out:
#                                                1    2    3    4    5    6  \
# Katy Perry - Never Really Over               145  204  222  250  182  300
# Taylor Swift - You Need To Calm Down          70  109  202  210  222  199
# Shawn Mendes & Camila Cabello - SeÃ±orita    322  640  569  659  666  744
# Ava Max - So Am I                             82  111  123   97  105  165
# Andreas Bourani - Auf uns                      1    1    3    3    2   31
# Meduza feat. Goodboys - Piece Of Your Heart    3    0    0    4    1    1
# Pietro Lombardi - Nur Ein Tanz                23   36   31   42   46   41
# Loud Luxury feat. brando - Body                8    0    2    1    0    1
# Mark Forster - Sowieso                        31   47   61   75   97  120
# Camila Cabello feat. Young Thug - Havana      74  117   99  143  123  128
#
#                                                7    8    9   10  ...   151  \
# Katy Perry - Never Really Over               391  376  377  349  ...    68
# Taylor Swift - You Need To Calm Down         205  226  297  362  ...   155
# Shawn Mendes & Camila Cabello - SeÃ±orita    750  769  781  835  ...   664
# Ava Max - So Am I                            308  299  326  304  ...   705
# Andreas Bourani - Auf uns                     27   12   29   56  ...   608
# Meduza feat. Goodboys - Piece Of Your Heart    0   10    8   10  ...   562
# Pietro Lombardi - Nur Ein Tanz                55   55   58   55  ...     9
# Loud Luxury feat. brando - Body                5   13    3    5  ...    39
# Mark Forster - Sowieso                       118  120  144  136  ...  1207
# Camila Cabello feat. Young Thug - Havana     126  147  126  153  ...   907
#
#                                               152   153   154   155   156  \
# Katy Perry - Never Really Over                 89    87    59    98   109
# Taylor Swift - You Need To Calm Down          147   148   172   160   134
# Shawn Mendes & Camila Cabello - SeÃ±orita     592   575   574   509   527
# Ava Max - So Am I                             756   705   667   734   687
# Andreas Bourani - Auf uns                     601   636   612   608   594
# Meduza feat. Goodboys - Piece Of Your Heart   570   689   626   597   653
# Pietro Lombardi - Nur Ein Tanz                  6     7    11     9     8
# Loud Luxury feat. brando - Body                41    41    46    55    40
# Mark Forster - Sowieso                       1256  1157  1238  1175  1144
# Camila Cabello feat. Young Thug - Havana      852   846   876   799   794
#
#                                               157   158   159   160
# Katy Perry - Never Really Over                 81   129    76    74
# Taylor Swift - You Need To Calm Down          147   197   123   146
# Shawn Mendes & Camila Cabello - SeÃ±orita     534   509   563   468
# Ava Max - So Am I                             713   757   706   774
# Andreas Bourani - Auf uns                     599   634   567   621
# Meduza feat. Goodboys - Piece Of Your Heart   654   684   703   790
# Pietro Lombardi - Nur Ein Tanz                  7     8     7     6
# Loud Luxury feat. brando - Body                42    36    41    42
# Mark Forster - Sowieso                       1336  1172  1186  1272
# Camila Cabello feat. Young Thug - Havana      842   831   792   773
#
# [10 rows x 160 columns]

# %%
# Define dataset with songs to train on
df_train = df[~df.index.isin(list_of_test_songs)]
df_train
# Out:
#                                                       1    2    3    4    5  \
# Adel Tawil - Unsere Lieder                           35   33   61   54  146
# Alec Benjamin Feat. Alessia Cara - Let Me Down ...    2    7   12   13   21
# Annenmaykantereit - Marie                            34   57   84   99  119
# Ariana Grande - 7 rings                             231  272  279  302  325
# Ava Max - Sweet but Psycho                           72  158  184  208  188
# Bausa - Was Du Liebe nennst                           1    3    2    4    8
# C Arma - Yapma - Radio Edit                           2    5    2    0    2
# Calvin Harris & Rag'n'bone Man - Giant              111  128  196  221  307
# Childish Gambino - This Is America                   25   51   46   48   37
# Chris Brown - Undecided                              41   68   75  108  111
# Christine and The Queens - Doesn't matter_Engli...    2    1    0    3    3
# David Guetta ft. Bebe Rexha J Balvin - Say My Name   22   27   21   20   17
# Daya - New                                            1    1    1    3    3
# Dean Lewis - Be Alright                               5    9    9   14   12
# Dermot Kennedy - Power Over Me                       17   30   31   35   38
# Die Lochis - Lieblingslied                            2    3    9   10    7
# DJ Regard - Ride It                                   1    0    0    0    1
# Dj Snake feat. Selena Gomez, Ozuna, Cardi B - T...   30   31   43   51   64
# Dominic Fike - 3 Nights                               9   13   13   12   14
# Dotan - Numb                                         43   70   77   81   68
# Dynoro & Gigi D'agostino - In My Mind                36   59   74   70   79
# Gaullin - Moonlight                                   1    2    3    5    3
# George Ezra - Pretty Shining People                  85  222  177  287  204
# GestÃ¶rt aber Geil & Koby Funk feat. Wincent We...    4    2    6   13    8
# GestÃ¶rt aber Geil feat. Sebastian HÃ¤mer - Ich...   17   22   30   38   26
# Glasperlenspiel - Geiles Leben                       20   35   25   25   28
# Joel Brandenstein - Diese Liebe                       8    0    2    0    0
# Johannes Oerding - An guten Tagen                    54   78   71   96   97
# Jonas Blue feat. Jack & Jack - Rise                  29   39   64  118  102
# Josh. - Cordula GrÃ¼n                                41   74   60   99   69
# ...                                                 ...  ...  ...  ...  ...
# Nf - Let You Down                                     7    5    4    5    6
# Notd feat. Bea Miller - I Wanna Know                  3    6   14   13    9
# Parov Stelar - All Night                              3    4    2    5    2
# Peter Fox - Alles Neu                                 4    2    4    5    2
# Philipp Dittberner - Das ist dein Leben               7   12   13   16   26
# Pietro Lombardi - PhÃ¤nomenal                        23   42   43   44   40
# Post Malone - Circles                                36   44   79  151  141
# Rebecca Ferguson - Bones                              2    0    0    5    1
# Robyn - Honey                                         3    5    2    4    7
# RosalÃ­a - MALAMENTE (Cap.1: Augurio)                
# RosalÃ­a - MALAMENTE (Cap.1: Augurio)                 6   11    8    7    6
# Sam Smith - How Do You Sleep?                       235  290  288  276  330
# Sarah Connor - Ich wÃ¼nsch dir                        8    6   29   29   35
# Sarah Connor - Vincent                               81  101  187  168  193
# Sarah Connor - Wie schÃ¶n du bist                    48   25   59   51   47
# Shirin David - Fliegst Du mit                        37   38   27   33   41
# Skott - Mermaid                                      21   23   20   24   15
# Soleima - Low Life                                    0    0    0    1    1
# Superorganism - Everybody Wants To Be Famous         52   48   54   59   72
# Taylor Swift feat. Brendon Urie - Me!               407  525  486  533  535
# The Script - The Last Time                           27   35   55   83   39
# TiÃ«sto, Dzeko feat. Preme, Post Malone - Jacki...   24   22   35   16   30
# Tim Bendzko - Keine Maschine                        206  203  270  266  333
# Tones And I - Dance Monkey                          982  909  807  941  969
# Wincent Weiss - Hier mit dir                        169  137  123  134  200
# Wincent Weiss - Kaum Erwarten                       191  149  247  208  207
# Xavier Naidoo - Bitte hÃ¶r nicht auf zu trÃ¤umen      6    5    5    2    2
# Xavier Naidoo - Gute Zeiten (mit MoTrip)             96   84   89  110  101
# Younotus & Janieck & Senex - Narcotic                92   91   97   93  102
# Yves Tumor - Applaud                                  1    0    0    1    0
# Zhu - Faded                                           7    9    4    7   11
#
#                                                     ...   151   152   153  \
# Adel Tawil - Unsere Lieder                          ...    33    35    34
# Alec Benjamin Feat. Alessia Cara - Let Me Down ...  ...   892   807   834
# Annenmaykantereit - Marie                           ...    31    33    32
# Ariana Grande - 7 rings                             ...   180   168   173
# Ava Max - Sweet but Psycho                          ...   864   869   919
# Bausa - Was Du Liebe nennst                         ...   360   306   287
# C Arma - Yapma - Radio Edit                         ...     1     1     3
# Calvin Harris & Rag'n'bone Man - Giant              ...   650   718   679
# Childish Gambino - This Is America                  ...    34    36    32
# Chris Brown - Undecided                             ...    24    21    40
# Christine and The Queens - Doesn't matter_Engli...  ...     0     0     1
# David Guetta ft. Bebe Rexha J Balvin - Say My Name  ...   485   487   478
# Daya - New                                          ...     1     0     1
# Dean Lewis - Be Alright                             ...  1046  1101  1083
# Dermot Kennedy - Power Over Me                      ...   821   874   803
# Die Lochis - Lieblingslied                          ...    18    17    16
# DJ Regard - Ride It                                 ...  1239  1241  1217
# Dj Snake feat. Selena Gomez, Ozuna, Cardi B - T...  ...   183   192   182
# Dominic Fike - 3 Nights                             ...   471   398   448
# Dotan - Numb                                        ...     4     4     2
# Dynoro & Gigi D'agostino - In My Mind               ...  1071  1013  1041
# Gaullin - Moonlight                                 ...   237   241   233
# George Ezra - Pretty Shining People                 ...    14    17    70
# GestÃ¶rt aber Geil & Koby Funk feat. Wincent We...  ...   138   170   194
# GestÃ¶rt aber Geil feat. Sebastian HÃ¤mer - Ich...  ...   154   128   145
# Glasperlenspiel - Geiles Leben                      ...    31    36    24
# Joel Brandenstein - Diese Liebe                     ...     2     0     1
# Johannes Oerding - An guten Tagen                   ...   608   633   587
# Jonas Blue feat. Jack & Jack - Rise                 ...  1002   981   943
# Josh. - Cordula GrÃ¼n                               ...    91    75    76
# ...                                                 ...   ...   ...   ...
# Nf - Let You Down                                   ...   262   210   199
# Notd feat. Bea Miller - I Wanna Know                ...     2     4     0
# Parov Stelar - All Night                            ...    33    29    18
# Peter Fox - Alles Neu                               ...     2    12    12
# Philipp Dittberner - Das ist dein Leben             ...   402   380   344
# Pietro Lombardi - PhÃ¤nomenal                       ...    21    23    24
# Post Malone - Circles                               ...  1057  1030   972
# Rebecca Ferguson - Bones                            ...     0     0     0
# Robyn - Honey                                       ...     7     6     8
# RosalÃ­a - MALAMENTE (Cap.1: Augurio
# Parov Stelar - All Night                              43    39    28
# Peter Fox - Alles Neu                                 12     7     2
# Philipp Dittberner - Das ist dein Leben              316   414   397
# Pietro Lombardi - PhÃ¤nomenal                         16    21    27
# Post Malone - Circles                               1019  1043  1011
# Rebecca Ferguson - Bones                               0     0     0
# Robyn - Honey                                          6     7     5
# RosalÃ­a - MALAMENTE (Cap.1: Augurio)                 11    10     5
# Sam Smith - How Do You Sleep?                        193   231   264
# Sarah Connor - Ich wÃ¼nsch dir                       337   294   271
# Sarah Connor - Vincent                               144   156   173
# Sarah Connor - Wie schÃ¶n du bist                    243   238   255
# Shirin David - Fliegst Du mit                          4     2     0
# Skott - Mermaid                                        0     1     0
# Soleima - Low Life                                     1     1     2
# Superorganism - Everybody Wants To Be Famous          13     9    10
# Taylor Swift feat. Brendon Urie - Me!                153   167   156
# The Script - The Last Time                             1     3     7
# TiÃ«sto, Dzeko feat. Preme, Post Malone - Jacki...   300   314   306
# Tim Bendzko - Keine Maschine                         250   196   143
# Tones And I - Dance Monkey                           722   774   793
# Wincent Weiss - Hier mit dir                         513   543   482
# Wincent Weiss - Kaum Erwarten                        325   314   348
# Xavier Naidoo - Bitte hÃ¶r nicht auf zu trÃ¤umen      10     3    10
# Xavier Naidoo - Gute Zeiten (mit MoTrip)               8     8    10
# Younotus & Janieck & Senex - Narcotic               1113  1143  1128
# Yves Tumor - Applaud                                   0     0     0
# Zhu - Faded                                          114   120   105
#
# [86 rows x 160 columns]

# %%
# Split train dataset into input and output days. Change value of input_days
n_steps_in = 56
number_of_total_days = 140
n_steps_out = number_of_total_days - n_steps_in


# define the train data input and output
train_input_data = df_train.iloc[:, 0:n_steps_in]
train_output_data = df_train.iloc[:, n_steps_in:number_of_total_days]

# Set X and y to train input and output data
train_input = array(train_input_data)
train_output = array(train_output_data)

# create scaler
x_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()
#x_scaler = StandardScaler()
#y_scaler = StandardScaler()

# fit scaler on data
train_input = x_scaler.fit_transform(train_input)
train_output = y_scaler.fit_transform(train_output)

print("Input days: ", len(train_input[0])) 
print("Output days: ", len(train_output[0]))
print("Example of first song input data: ", train_input[0])
print("Example of first song output data: ", train_output[0])
# Out:
# Input days:  56
# Output days:  84
# Example of first song input data:  [0.06415094 0.04551724 0.08047493 0.06569343 0.16609784 0.16802444
#  0.20682068 0.24659232 0.22529224 0.12899897 0.21546392 0.15384615
#  0.20223577 0.28       0.22105263 0.28286015 0.27953586 0.32606325
#  0.3012884  0.22156863 0.25652174 0.23733863 0.26130199 0.23396567
#  0.1776824  0.18648208 0.24599832 0.1875     0.23318777 0.23032787
#  0.22742475 0.19167389 0.2393968  0.14117647 0.14876033 0.17612688
#  0.22922135 0.23240589 0.17166667 0.16450567 0.15553677 0.12048193
#  0.10428016 0.12999217 0.13371151 0.13974895 0.13349321 0.1123506
#  0.15303644 0.17455392 0.10380349 0.1541411  0.14463453 0.12555721
#  0.12441315 0.20654716]
# Example of first song output data:  [0.14834337 0.14383043 0.15789474 0.16271722 0.16958599 0.16905901
#  0.21131186 0.18368963 0.25161812 0.18892508 0.1674277  0.23014587
#  0.18779715 0.11195735 0.06338553 0.06571655 0.05942948 0.08715596
#  0.08273667 0.08034321 0.19014627 0.1983346  0.23909657 0.19450801
#  0.23861852 0.19519752 0.18833087 0.17275495 0.18644068 0.22012579
#  0.1875     0.23365231 0.18073248 0.17932655 0.15996719 0.11336336
#  0.1347729  0.1884058  0.16597853 0.19685039 0.0798722  0.08233413
#  0.03657523 0.08982512 0.05582137 0.08989658 0.11268716 0.08491344
#  0.07177033 0.04714065 0.07435508 0.08748978 0.07261247 0.04953032
#  0.03663614 0.04298459 0.02664577 0.04467912 0.032      0.05068383
#  0.03715415 0.02755267 0.04344392 0.02838063 0.03174603 0.03425775
#  0.03005686 0.04829309 0.03891709 0.04383788 0.04587935 0.04067797
#  0.0512605  0.03539095 0.03492334 0.01353638 0.02122241 0.01662292
#  0.03058624 0.03800676 0.03672075 0.02627119 0.04564315 0.02941176]

# %%
# Split test dataset into input and output days.

# define the test data input and output
test_input_data = df_test.iloc[:, 0:n_steps_in]
test_output_data = df_test.iloc[:, n_steps_in:number_of_total_days]

# Set X and y to train input and output data
test_input = array(test_input_data)
test_output = array(test_output_data)

# transform data
test_input = x_scaler.transform(test_input)

print("Input days: ", len(test_input[0])) 
print("Output days: ", len(test_output[0]))
print("Example of first song input data: ", test_input[0])
print("Example of first song output data: ", test_output[0])
# Out:
# Input days:  56
# Output days:  84
# Example of first song input data:  [0.27169811 0.28137931 0.29287599 0.30413625 0.20705347 0.30549898
#  0.43014301 0.46592317 0.40063762 0.36016512 0.4185567  0.44046365
#  0.42378049 0.42555556 0.42526316 0.47634069 0.41772152 0.5997819
#  0.43904856 0.56470588 0.48586957 0.52631579 0.49276673 0.53026197
#  0.47296137 0.50732899 0.50631845 0.44724026 0.57117904 0.55409836
#  0.52508361 0.56027754 0.64844486 0.53109244 0.47272727 0.5542571
#  0.61854768 0.52209493 0.5775     0.54619125 0.54691462 0.5253012
#  0.51361868 0.55050901 0.53403566 0.54476987 0.53317346 0.52988048
#  0.56923077 0.59038014 0.59984152 0.55138037 0.6251944  0.5936107
#  0.57746479 0.61808262]
# Example of first song output data:  [782 826 771 774 696 728 672 739 710 711 700 773 755 737 731 781 780 835
#  760 799 775 712 701 732 724 657 709 697 649 671 627 619 681 489 572 582
#  521 516 523 457 422 440 442 428 362 415 410 407 360 424 375 350 340 343
#  327 192 239 193 193 207 214 164 133 215 173 156 200 142 169 159 190 127
#  122 129 167 140 127 140 162  95 102 151  94 135]

# %%
# univariate multi-step vector-output 1d cnn example (Manual radio plays)


# reshape from [samples, timesteps] into [samples, timesteps, features]
n_features = 1
train_input = train_input.reshape((train_input.shape[0], train_input.shape[1], n_features))
test_input = test_input.reshape((test_input.shape[0], n_steps_in, n_features))

# define model


# LSTM Model
model = Sequential()
model.add(LSTM(100, return_sequences=True, input_shape=(n_steps_in, n_features)))
model.add(LeakyReLU(alpha=0.1))
model.add(LSTM(100))
model.add(LeakyReLU(alpha=0.1))
#model.add(LeakyReLU(alpha=0.5))
#model.add(Dropout(0.5))
#model.add(MaxPooling1D(pool_size=2))
#model.add(Flatten())
#model.add(Dense(50, activation='relu'))
model.add(Dense(n_steps_out))
model.compile(loss='mean_squared_error', optimizer='adam')

history = model.fit(train_input, train_output, epochs=10000, batch_size=8, validation_data=(test_input, test_output), 
                    callbacks=[EarlyStopping(monitor='val_loss', patience=10)], verbose=1, shuffle=False)

yhat = history

model.summary()
# Out:
# WARNING:tensorflow:From /Users/clausholm/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/clausholm/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 86 samples, validate on 10 samples
# Epoch 1/10000
# 86/86 [==============================] - 1s 14ms/step - loss: 0.1522 - val_loss: 443180.5625
# Epoch 2/10000
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0807 - val_loss: 442928.7250
# Epoch 3/10000
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0408 - val_loss: 442811.0375
# Epoch 4/10000
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0318 - val_loss: 442826.6875
# Epoch 5/10000
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0265 - val_loss: 442833.7750
# Epoch 6/10000
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0265 - val_loss: 442699.7250
# Epoch 7/10000
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0238 - val_loss: 442710.2625
# Epoch 8/10000
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0222 - val_loss: 442750.1250
# Epoch 9/10000
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0231 - val_loss: 442744.6875
# Epoch 10/10000
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0199 - val_loss: 442735.8250
# Epoch 11/10000
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0212 - val_loss: 442712.4500
# Epoch 12/10000
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0192 - val_loss: 442719.6250
# Epoch 13/10000
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0193 - val_loss: 442727.7500
# Epoch 14/10000
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0185 - val_loss: 442747.7750
# Epoch 15/10000
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0192 - val_loss: 442758.5000
# Epoch 16/10000
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0193 - val_loss: 442795.8750
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 56, 100)           40800
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 56, 100)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                8484
# =================================================================
# Total params: 129,684
# Trainable params: 129,684
# Non-trainable params: 0
# _________________________________________________________________

# %%
# demonstrate prediction
yhat = model.predict(test_input, verbose=0)
print("predicticted time series output: ", yhat)

# transform data back to original scale
yhat = y_scaler.inverse_transform(yhat)

# Define the first expected and predicted
expected = test_output[0]
predictions = yhat[0]
print("Expected time series output: ", expected)
print("Predicted time series output: ", predictions)
# Out:
# predicticted time series output:  [[ 4.28027809e-01  4.74861115e-01  4.65539128e-01  4.56997484e-01
#    4.73370492e-01  4.77822870e-01  4.87841249e-01  5.03690720e-01
#    5.10602593e-01  5.45113921e-01  4.83819902e-01  5.38118303e-01
#    4.94921356e-01  4.77911174e-01  5.13928354e-01  5.24991572e-01
#    5.38806617e-01  5.36650717e-01  5.38922369e-01  5.45532227e-01
#    5.06392062e-01  5.21265507e-01  5.75867057e-01  5.37599325e-01
#    5.35362840e-01  5.39244831e-01  4.98915076e-01  5.23712814e-01
#    5.35822392e-01  5.48455358e-01  5.54134071e-01  5.56047857e-01
#    5.33468246e-01  5.66030681e-01  5.91706097e-01  5.26692569e-01
#    5.14209270e-01  5.44722080e-01  6.03375673e-01  5.79331160e-01
#    6.03237331e-01  5.76083183e-01  5.99419832e-01  5.36548615e-01
#    5.70945978e-01  5.65448403e-01  5.28055966e-01  5.69045782e-01
#    5.79948664e-01  5.49256623e-01  5.24130344e-01  5.87471187e-01
#    5.53818822e-01  5.90299606e-01  5.46223402e-01  5.59510171e-01
#    5.73377252e-01  5.71450114e-01  5.72221220e-01  5.63084960e-01
#    5.62116146e-01  5.67218900e-01  5.36631525e-01  5.59857309e-01
#    5.58856726e-01  5.68293154e-01  5.55324256e-01  5.42921960e-01
#    5.51748931e-01  5.69957793e-01  5.65934777e-01  5.33916414e-01
#    5.36670268e-01  5.43619573e-01  5.31516969e-01  5.15681386e-01
#  688.59174 739.4133  704.7927  682.05225 696.1651  675.531   688.1586
#  695.49744 697.6352  700.4255  697.284   670.03613 722.82117 721.28973
#  701.5545  690.58307 714.1307  730.6879  735.75055 755.2531  720.68005
#  721.10205 674.97815 715.96625 710.7686  670.103   690.25256 727.2556
#  710.7381  690.8038  718.47723 701.6885  691.24084 656.0143  689.87604
#  731.6294  703.4551  715.27655 699.9146  711.0769  699.9481  679.3755
#  670.70905 668.9515  696.7274  683.6042  652.04926 652.16724 689.079
#  666.1052  630.02136 638.63763 660.4978  624.0009  609.5354  620.8832
#  626.81885 648.5688  644.30707 641.62573 635.0699  608.9087  604.7223 ]

# %%
# Create variable for each song, used to compare predicted and true value
lst1 = [test_output[0], yhat[0]]
lst2 = [test_output[1], yhat[1]]
lst3 = [test_output[2], yhat[2]]
lst4 = [test_output[3], yhat[3]]
lst5 = [test_output[4], yhat[4]]
lst6 = [test_output[5], yhat[5]]
lst7 = [test_output[6], yhat[6]]
lst8 = [test_output[7], yhat[7]]
lst9 = [test_output[8], yhat[8]]
lst10 = [test_output[9], yhat[9]]

# Set value for labelling
daysOrWeeks = 'Days'

# Make dataset of test song variables
df1 = pd.DataFrame(lst1).T
df1.columns = ['True', 'Predicted']
df1[daysOrWeeks] = df1.index + n_steps_in
df1.set_index(daysOrWeeks,inplace=True)

df2 = pd.DataFrame(lst2).T
df2.columns = ['True', 'Predicted']
df2[daysOrWeeks] = df2.index + n_steps_in
df2.set_index(daysOrWeeks,inplace=True)

df3 = pd.DataFrame(lst3).T
df3.columns = ['True', 'Predicted']
df3[daysOrWeeks] = df3.index + n_steps_in
df3.set_index(daysOrWeeks,inplace=True)

df4 = pd.DataFrame(lst4).T
df4.columns = ['True', 'Predicted']
df4[daysOrWeeks] = df4.index + n_steps_in
df4.set_index(daysOrWeeks,inplace=True)

df5 = pd.DataFrame(lst5).T
df5.columns = ['True', 'Predicted']
df5[daysOrWeeks] = df5.index + n_steps_in
df5.set_index(daysOrWeeks,inplace=True)

df6 = pd.DataFrame(lst6).T
df6.columns = ['True', 'Predicted']
df6[daysOrWeeks] = df6.index + n_steps_in
df6.set_index(daysOrWeeks,inplace=True)

df7 = pd.DataFrame(lst7).T
df7.columns = ['True', 'Predicted']
df7[daysOrWeeks] = df7.index + n_steps_in
df7.set_index(daysOrWeeks,inplace=True)

df8 = pd.DataFrame(lst8).T
df8.columns = ['True', 'Predicted']
df8[daysOrWeeks] = df8.index + n_steps_in
df8.set_index(daysOrWeeks,inplace=True)

df9 = pd.DataFrame(lst9).T
df9.columns = ['True', 'Predicted']
df9[daysOrWeeks] = df9.index + n_steps_in
df9.set_index(daysOrWeeks,inplace=True)

df10 = pd.DataFrame(lst10).T
df10.columns = ['True', 'Predicted']
df10[daysOrWeeks] = df10.index + n_steps_in
df10.set_index(daysOrWeeks,inplace=True)

# %%
# Forecast Error (or Residual Forecast Error)
forecast_errors = [test_output[i]-yhat[i] for i in range(len(test_output))]  

df_result = pd.DataFrame(columns=['Song', 'Date', 'Bias', 'MAE', 'MAPE', 'MSE', 'RMSE', 'RMSPE', 'Predict_from', 'Predict_to'])

def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def root_mean_square_percentage_error(y_true, y_pred):
    loss = np.sqrt(np.mean(np.square(((y_true - y_pred) / y_true)), axis=0)) * 100
    return loss

for i in range(len(test_output)):
    print(list_of_test_songs[i])

    # Mean Forecast Error (or Forecast Bias), Mean Absolute Error, Mean Squared Error, Root Mean Squared Error  
    bias = mean(forecast_errors[i])
    mae = mean(abs(forecast_errors[i]))
    mape = mean_absolute_percentage_error(test_output[i], yhat[i])
    mse = mean_squared_error(test_output[i], yhat[i]) 
    rmse = sqrt(mse)
    rmspe = root_mean_square_percentage_error(test_output[i], yhat[i])
    df_result = df_result.append({'Date': date.today(),'Song': list_of_test_songs[i], 'Bias': bias, 'MAE': mae, 'MAPE': mape, 'MSE': mse, 'RMSE': rmse, 'RMSPE': rmspe, 'Predict_from':n_steps_in, 'Predict_to': number_of_total_days}, ignore_index=True)
    
    print('Bias: %f' % bias)
    print('MAE: %f' % mae)
    print('MAPE: %f'% mape)
    print('MSE: %f' % mse)
    print('RMSE: %f' % rmse)
    print('RMSPE %f' % rmspe)
    print('_________________________')

# Create datetime for time of results    
now = datetime.datetime.now()
now = str(now.strftime("%Y-%m-%d %H:%M:%S"))

# Save Results to csv file in folder
#df_result.to_csv(folder_name+'/'+identify+'_'+now+'.csv', sep=';', decimal=',' )

df_result
# Out:
# Katy Perry - Never Really Over
# Bias: -219.062155
# MAE: 279.583152
# MAPE: 138.172555
# MSE: 112732.081190
# RMSE: 335.755985
# RMSPE 208.353214
# _________________________
# Taylor Swift - You Need To Calm Down
# Bias: -43.992266
# MAE: 109.589409
# MAPE: 27.210623
# MSE: 17100.983110
# RMSE: 130.770727
# RMSPE 37.596402
# _________________________
# Shawn Mendes & Camila Cabello - SeÃ±orita
# Bias: -116.724597
# MAE: 162.053914
# MAPE: 17.827329
# MSE: 36458.990707
# RMSE: 190.942375
# RMSPE 22.362610
# _________________________
# Ava Max - So Am I
# Bias: 198.128738
# MAE: 198.694792
# MAPE: 19.754430
# MSE: 51431.686165
# RMSE: 226.785551
# RMSPE 21.946387
# _________________________
# Andreas Bourani - Auf uns
# Bias: 223.779229
# MAE: 227.375614
# MAPE: 41.027408
# MSE: 63575.986046
# RMSE: 252.142789
# RMSPE 42.607356
# _________________________
# Meduza feat. Goodboys - Piece Of Your Heart
# Bias: 77.382518
# MAE: 102.961250
# MAPE: 33.801754
# MSE: 22591.209317
# RMSE: 150.303724
# RMSPE 41.605595
# _________________________
# Pietro Lombardi - Nur Ein Tanz
# Bias: -42.707191
# MAE: 43.055189
# MAPE: 383.444369
# MSE: 2308.066320
# RMSE: 48.042339
# RMSPE 482.306767
# _________________________
# Loud Luxury feat. brando - Body
# Bias: -10.394829
# MAE: 14.197112
# MAPE: 110.652127
# MSE: 299.248294
# RMSE: 17.298795
# RMSPE 139.448077
# _________________________
# Mark Forster - Sowieso
# Bias: 277.552508
# MAE: 277.552508
# MAPE: 30.448739
# MSE: 106651.433797
# RMSE: 326.575311
# RMSPE 33.342318
# _________________________
# Camila Cabello feat. Young Thug - Havana
# Bias: 136.134975
# MAE: 136.715207
# MAPE: 15.026584
# MSE: 23705.821443
# RMSE: 153.966949
# RMSPE 16.674129
# _________________________
#                                           Song        Date      Bias      MAE  \
# 0               Katy Perry - Never Really Over  2020-06-06 -219.0622 279.5832
# 1         Taylor Swift - You Need To Calm Down  2020-06-06  -43.9923 109.5894
# 2    Shawn Mendes & Camila Cabello - SeÃ±orita  2020-06-06 -116.7246 162.0539
# 3                            Ava Max - So Am I  2020-06-06  198.1287 198.6948
# 4                    Andreas Bourani - Auf uns  2020-06-06  223.7792 227.3756
# 5  Meduza feat. Goodboys - Piece Of Your Heart  2020-06-06   77.3825 102.9613
# 6               Pietro Lombardi - Nur Ein Tanz  2020-06-06  -42.7072  43.0552
# 7              Loud Luxury feat. brando - Body  2020-06-06  -10.3948  14.1971
# 8                       Mark Forster - Sowieso  2020-06-06  277.5525 277.5525
# 9     Camila Cabello feat. Young Thug - Havana  2020-06-06  136.1350 136.7152
#
#       MAPE         MSE     RMSE    RMSPE Predict_from Predict_to
# 0 138.1726 112732.0812 335.7560 208.3532           56        140
# 1  27.2106  17100.9831 130.7707  37.5964           56        140
# 2  17.8273  36458.9907 190.9424  22.3626           56        140
# 3  19.7544  51431.6862 226.7856  21.9464           56        140
# 4  41.0274  63575.9860 252.1428  42.6074           56        140
# 5  33.8018  22591.2093 150.3037  41.6056           56        140
# 6 383.4444   2308.0663  48.0423 482.3068           56        140
# 7 110.6521    299.2483  17.2988 139.4481           56        140
# 8  30.4487 106651.4338 326.5753  33.3423           56        140
# 9  15.0266  23705.8214 153.9669  16.6741           56        140

# %%
# Define plotting of graphs and saving them to folder
import matplotlib.pyplot as plt 

pred_title = "Prediction from "+ str(n_steps_in)+" to "+str(number_of_total_days)
fig_size = 1700

df1.plot()
plt.ylim((0,fig_size))
plt.title(list_of_test_songs[0])
plt.suptitle(pred_title)
#plt.savefig(folder_name+'/'+list_of_test_songs[0]+ '_'+ identify +'.png')
plt.show()
plt.close()
print("Song: ", list_of_test_songs[0])
print(pred_title)
print('________________________________________________________________')

df2.plot()
plt.ylim((0,fig_size))
plt.title(list_of_test_songs[1])
plt.suptitle(pred_title)
#plt.savefig(folder_name+'/'+list_of_test_songs[1]+ '_'+ identify +'.png')
plt.show()
plt.close()
print("Song: ", list_of_test_songs[1])
print("Prediction from", n_steps_in, "to", number_of_total_days)
print('________________________________________________________________')

df3.plot()
plt.ylim((0,fig_size))
plt.title(list_of_test_songs[2])
plt.suptitle(pred_title)
#plt.savefig(folder_name+'/'+list_of_test_songs[2]+ '_'+ identify +'.png')
plt.show()
plt.close()
print("Song: ", list_of_test_songs[2])
print("Prediction from", n_steps_in, "to", number_of_total_days)
print('________________________________________________________________')

df4.plot()
plt.ylim((0,fig_size))
plt.title(list_of_test_songs[3])
plt.suptitle(pred_title)
#plt.savefig(folder_name+'/'+list_of_test_songs[3]+ '_'+ identify +'.png')
plt.show()
plt.close()
print("Song: ", list_of_test_songs[3])
print("Prediction from", n_steps_in, "to", number_of_total_days)
print('________________________________________________________________')

df5.plot()
plt.ylim((0,fig_size))
plt.title(list_of_test_songs[4])
plt.suptitle(pred_title)
#plt.savefig(folder_name+'/'+list_of_test_songs[4]+ '_'+ identify +'.png')
plt.show()
plt.close()
print("Song: ", list_of_test_songs[4])
print("Prediction from", n_steps_in, "to", number_of_total_days)
print('________________________________________________________________')

df6.plot()
plt.ylim((0,fig_size))
plt.title(list_of_test_songs[5])
plt.suptitle(pred_title)
#plt.savefig(folder_name+'/'+list_of_test_songs[5]+ '_'+ identify +'.png')
plt.show()
plt.close()
print("Song: ", list_of_test_songs[5])
print("Prediction from", n_steps_in, "to", number_of_total_days)
print('________________________________________________________________')

df7.plot()
plt.ylim((0,fig_size))
plt.title(list_of_test_songs[6])
plt.suptitle(pred_title)
#plt.savefig(folder_name+'/'+list_of_test_songs[6]+ '_'+ identify +'.png')
plt.show()
plt.close()
print("Song: ", list_of_test_songs[6])
print("Prediction from", n_steps_in, "to", number_of_total_days)
print('________________________________________________________________')

df8.plot()
plt.ylim((0,fig_size))
plt.title(list_of_test_songs[7])
plt.suptitle(pred_title)
#plt.savefig(folder_name+'/'+list_of_test_songs[7]+ '_'+ identify +'.png')
plt.show()
plt.close()
print("Song: ", list_of_test_songs[7])
print("Prediction from", n_steps_in, "to", number_of_total_days)
print('________________________________________________________________')

df9.plot()
plt.ylim((0,fig_size))
plt.title(list_of_test_songs[8])
plt.suptitle(pred_title)
#plt.savefig(folder_name+'/'+list_of_test_songs[8]+ '_'+ identify +'.png')
plt.show()
plt.close()
print("Song: ", list_of_test_songs[8])
print("Prediction from", n_steps_in, "to", number_of_total_days)
print('________________________________________________________________')

df10.plot()
plt.ylim((0,fig_size))
plt.title(list_of_test_songs[9])
plt.suptitle(pred_title)
#plt.savefig(folder_name+'/'+list_of_test_songs[9]+ '_'+ identify +'.png')
plt.show()
plt.close()
print("Song: ", list_of_test_songs[9])
print("Prediction from", n_steps_in, "to", number_of_total_days)
print('________________________________________________________________')
# Out:
# Song:  Katy Perry - Never Really Over
# Prediction from 56 to 140
# ________________________________________________________________
# Song:  Taylor Swift - You Need To Calm Down
# Prediction from 56 to 140
# ________________________________________________________________
# Song:  Shawn Mendes & Camila Cabello - SeÃ±orita
# Prediction from 56 to 140
# ________________________________________________________________
# Song:  Ava Max - So Am I
# Prediction from 56 to 140
# ________________________________________________________________
# Song:  Andreas Bourani - Auf uns
# Prediction from 56 to 140
# ________________________________________________________________
# Song:  Meduza feat. Goodboys - Piece Of Your Heart
# Prediction from 56 to 140
# ________________________________________________________________
# Song:  Pietro Lombardi - Nur Ein Tanz
# Prediction from 56 to 140
# ________________________________________________________________
# Song:  Loud Luxury feat. brando - Body
# Prediction from 56 to 140
# ________________________________________________________________
# Song:  Mark Forster - Sowieso
# Prediction from 56 to 140
# ________________________________________________________________
# Song:  Camila Cabello feat. Young Thug - Havana
# Prediction from 56 to 140
# ________________________________________________________________
